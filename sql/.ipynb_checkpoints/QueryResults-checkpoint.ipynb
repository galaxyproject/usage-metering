# %%
import pandas as pd

# %%
numjobs_numusers = pd.read_csv('/Users/peiyuanp/Desktop/Galaxy_Summer2021/query_results/unprocessed_toolid/numjobs_numusers.txt',delimiter = "|",names = [])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/wn/pjr6ql195_9b749584z0l0cw0000gn/T/ipykernel_23585/462862233.py in <module>
# ----> 1 numjobs_numusers = pd.read_csv('/Users/peiyuanp/Desktop/Galaxy_Summer2021/query_results/unprocessed_toolid/numjobs_numusers.txt',delimiter = "|",names = [])
#
# NameError: name 'pd' is not defined

# %%
query1_all = pd.read_csv('/Users/peiyuanp/Desktop/Galaxy_Summer2021/Query_results/query1_all.txt',delimiter = '|',names = ['tool_id','month_year','num_jobs'])
query1_all = query1_all.dropna()
query1_all = query1_all.iloc[2:]

query1_all['tool_name'] = '0'
query1_all['tool_version'] = '0'

for i in range(len(query1_all)):
    query1_all['tool_name'].iloc[i]= getName(query1_all['tool_id'].iloc[i])
    query1_all['tool_version'].iloc[i]= getVersion(query1_all['tool_id'].iloc[i])

# %%
query1_all.drop(columns = ['tool_id'])
# Out:
#          month_year   num_jobs  \
# 3       2020-1           20627
# 4       2020-1            9204
# 5       2020-1            8743
# 6       2020-1            7631
# 7       2020-1            6492
# ...             ...        ...
# 23206   2021-5               1
# 23207   2021-5               1
# 23208   2021-5               1
# 23209   2021-5               1
# 23210   2021-5               1
#
#                                                tool_name  \
# 3                                                 fastqc
# 4       CONVERTER_gz_to_uncompressed                 ...
# 5                                          featurecounts
# 6                                                 hisat2
# 7                                            trimmomatic
# ...                                                  ...
# 23206                               EMBOSS: tranalign100
# 23207                         bcftools_plugin_fill_an_ac
# 23208                        bcftools_plugin_missing2ref
# ...

# %%
query2_all = pd.read_csv('/Users/peiyuanp/Desktop/Galaxy_Summer2021/Query_results/query2_all.txt',delimiter = '|',names = ['tool_id','month_year','total_cpu_time'])
query2_all = query2_all.dropna()
query2_all = query2_all.iloc[2:]

query2_all['tool_name'] = '0'
query2_all['tool_version'] = '0'

for i in range(len(query2_all)):
    query2_all['tool_name'].iloc[i]= getName(query2_all['tool_id'].iloc[i])
    query2_all['tool_version'].iloc[i]= getVersion(query2_all['tool_id'].iloc[i])

query2_all = query2_all.drop(columns = ['tool_id'])
query2_all.to_csv('query2_all.csv')

# %%
query3_all = pd.read_csv('/Users/peiyuanp/Desktop/Galaxy_Summer2021/Query_results/query3_all.txt',delimiter = '|',names = ['tool_id','month_year','avg_cpu_time'])
query3_all = query3_all.dropna()
query3_all = query3_all.iloc[2:]

query3_all['tool_name'] = '0'
query3_all['tool_version'] = '0'

for i in range(len(query3_all)):
    query3_all['tool_name'].iloc[i]= getName(query3_all['tool_id'].iloc[i])
    query3_all['tool_version'].iloc[i]= getVersion(query3_all['tool_id'].iloc[i])

query3_all.to_csv('query3_all.csv')

# %%
query4_all = pd.read_csv('/Users/peiyuanp/Desktop/Galaxy_Summer2021/Query_results/query4_all.txt',delimiter = '|',names = ['month_year','tool_id','totalmemory'])
query4_all = query4_all.dropna()
query4_all = query4_all.iloc[2:]

query4_all['tool_name'] = '0'
query4_all['tool_version'] = '0'

for i in range(len(query4_all)):
    query4_all['tool_name'].iloc[i]= getName(query4_all['tool_id'].iloc[i])
    query4_all['tool_version'].iloc[i]= getVersion(query4_all['tool_id'].iloc[i])

query4_all.to_csv('query4_all.csv')

# %%
query5_all = pd.read_csv('/Users/peiyuanp/Desktop/Galaxy_Summer2021/Query_results/query5_all.txt',delimiter = '|',names = ['month_year','tool_id','avgmemory'])
query5_all = query5_all.dropna()
query5_all = query5_all.iloc[2:]

query5_all['tool_name'] = '0'
query5_all['tool_version'] = '0'

for i in range(len(query5_all)):
    query5_all['tool_name'].iloc[i]= getName(query5_all['tool_id'].iloc[i])
    query5_all['tool_version'].iloc[i]= getVersion(query5_all['tool_id'].iloc[i])

query5_all.to_csv('query5_all.csv')

# %%
query6_all = pd.read_csv('/Users/peiyuanp/Desktop/Galaxy_Summer2021/Query_results/query6_all.txt',delimiter = '|',names = ['month_year','tool_id','numusers'])
query6_all = query6_all.dropna()
query6_all = query6_all.iloc[2:]

query6_all['tool_name'] = '0'
query6_all['tool_version'] = '0'

for i in range(len(query6_all)):
    query6_all['tool_name'].iloc[i]= getName(query6_all['tool_id'].iloc[i])
    query6_all['tool_version'].iloc[i]= getVersion(query6_all['tool_id'].iloc[i])

query6_all.to_csv('query6_all.csv')

# %%
query1_May2021 = pd.read_csv('/Users/peiyuanp/Desktop/Galaxy_Summer2021/Query_results/query1_May2021.txt',delimiter = '|',names = ['tool_id','month_year','numjobs'])
query1_May2021 = query1_May2021.dropna()
query1_May2021 = query1_May2021.iloc[2:]

query1_May2021['tool_name'] = '0'
query1_May2021['tool_version'] = '0'

for i in range(len(query1_May2021)):
    query1_May2021['tool_name'].iloc[i]= getName(query1_May2021['tool_id'].iloc[i])
    query1_May2021['tool_version'].iloc[i]= getVersion(query1_May2021['tool_id'].iloc[i])

query1_May2021.to_csv('query1_May2021.csv')

# %%
query2_May2021 = pd.read_csv('/Users/peiyuanp/Desktop/Galaxy_Summer2021/Query_results/query2_May2021.txt',delimiter = '|',names = ['tool_id','month_year','total_cpu_time'])
query2_May2021 = query2_May2021.dropna()
query2_May2021 = query2_May2021.iloc[2:]

query2_May2021['tool_name'] = '0'
query2_May2021['tool_version'] = '0'

for i in range(len(query2_May2021)):
    query2_May2021['tool_name'].iloc[i]= getName(query2_May2021['tool_id'].iloc[i])
    query2_May2021['tool_version'].iloc[i]= getVersion(query2_May2021['tool_id'].iloc[i])

query2_May2021.to_csv('query2_May2021.csv')

# %%
query3_May2021 = pd.read_csv('/Users/peiyuanp/Desktop/Galaxy_Summer2021/Query_results/query3_May2021.txt',delimiter = '|',names = ['tool_id','month_year','avg_cpu_time'])
query3_May2021 = query3_May2021.dropna()
query3_May2021 = query3_May2021.iloc[2:]

query3_May2021['tool_name'] = '0'
query3_May2021['tool_version'] = '0'

for i in range(len(query3_May2021)):
    query3_May2021['tool_name'].iloc[i]= getName(query3_May2021['tool_id'].iloc[i])
    query3_May2021['tool_version'].iloc[i]= getVersion(query3_May2021['tool_id'].iloc[i])

query3_May2021.to_csv('query3_May2021.csv')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# /var/folders/wn/pjr6ql195_9b749584z0l0cw0000gn/T/ipykernel_9993/1643156888.py in <module>
# ----> 1 query3_May2021 = pd.read_csv('/Users/peiyuanp/Desktop/Galaxy_Summer2021/Query_results/query3_May2021.txt',delimiter = '|',names = ['tool_id','month_year','avg_cpu_time'])
#       2 query3_May2021 = query3_May2021.dropna()
#       3 query3_May2021 = query3_May2021.iloc[2:]
#       4
#       5 query3_May2021['tool_name'] = '0'
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
query4_May2021 = pd.read_csv('/Users/peiyuanp/Desktop/Galaxy_Summer2021/Query_results/query4_May2021.txt',delimiter = '|',names = ['month_year','tool_id','totalmemory'])
query4_May2021 = query4_May2021.dropna()
query4_May2021 = query4_May2021.iloc[2:]

query4_May2021['tool_name'] = '0'
query4_May2021['tool_version'] = '0'

for i in range(len(query4_May2021)):
    query4_May2021['tool_name'].iloc[i]= getName(query4_May2021['tool_id'].iloc[i])
    query4_May2021['tool_version'].iloc[i]= getVersion(query4_May2021['tool_id'].iloc[i])

query4_May2021.to_csv('query4_May2021.csv')

# %%
query5_May2021 = pd.read_csv('/Users/peiyuanp/Desktop/Galaxy_Summer2021/Query_results/query5_May2021.txt',delimiter = '|',names = ['month_year','tool_id','avgmemory'])
query5_May2021 = query5_May2021.dropna()
query5_May2021 = query5_May2021.iloc[2:]

query5_May2021['tool_name'] = '0'
query5_May2021['tool_version'] = '0'

for i in range(len(query5_May2021)):
    query5_May2021['tool_name'].iloc[i]= getName(query5_May2021['tool_id'].iloc[i])
    query5_May2021['tool_version'].iloc[i]= getVersion(query5_May2021['tool_id'].iloc[i])

query5_May2021.to_csv('query5_May2021.csv')

# %%
query6_May2021 = pd.read_csv('/Users/peiyuanp/Desktop/Galaxy_Summer2021/Query_results/query6_May2021.txt',delimiter = '|',names = ['month_year','tool_id','numusers'])
query6_May2021 = query6_May2021.dropna()
query6_May2021 = query6_May2021.iloc[2:]

query6_May2021['tool_name'] = '0'
query6_May2021['tool_version'] = '0'

for i in range(len(query6_May2021)):
    query6_May2021['tool_name'].iloc[i]= getName(query6_May2021['tool_id'].iloc[i])
    query6_May2021['tool_version'].iloc[i]= getVersion(query6_May2021['tool_id'].iloc[i])

query6_May2021.to_csv('query6_May2021.csv')

# %%
query1_all.to_csv('query1_all.csv')

# %%
def getName(str):
    arr = str.split('/')
    return arr[len(arr) - 2]

# %%
def getVersion(str):
    arr = str.split('/')
    return arr[len(arr) - 1]
